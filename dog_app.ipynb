# %% [markdown]
# # 🐶 Dog Detection Web App (Flask + PyTorch)
#
# Upload an image and detect if it is a dog.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt

# ===== LOAD MODEL =====
model = models.resnet18(weights=None)
model.fc = nn.Linear(model.fc.in_features, 2)
model.load_state_dict(torch.load("model.pt", map_location='cpu'))
model.eval()

# ===== TRANSFORM =====
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# ===== LOAD ẢNH =====
image = Image.open("4.jpg").convert("RGB")  # 👈 đổi tên ảnh tại đây

# ===== HIỂN THỊ ẢNH =====
plt.imshow(image)
plt.axis('off')
plt.show()

# ===== DỰ ĐOÁN =====
image_tensor = transform(image).unsqueeze(0)

with torch.no_grad():
    outputs = model(image_tensor)
    probs = F.softmax(outputs, dim=1)

    dog_prob = probs[0][0].item()  # dog = index 0
    _, predicted = torch.max(outputs, 1)

# ===== KẾT QUẢ =====
if predicted.item() == 0 and dog_prob > 0.5:
    print(f"🐶 Đây là CHÓ ({dog_prob:.2f})")
else:
    print(f"❌ Không phải chó ({dog_prob:.2f})")
# Out:
# ❌ Không phải chó (0.00)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt

# ===== LOAD MODEL =====
model = models.resnet18(weights=None)
model.fc = nn.Linear(model.fc.in_features, 2)
model.load_state_dict(torch.load("model.pt", map_location='cpu'))
model.eval()

# ===== TRANSFORM =====
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# ===== LOAD ẢNH =====
image = Image.open("1.jpg").convert("RGB")  # 👈 đổi tên ảnh tại đây

# ===== HIỂN THỊ ẢNH =====
plt.imshow(image)
plt.axis('off')
plt.show()

# ===== DỰ ĐOÁN =====
image_tensor = transform(image).unsqueeze(0)

with torch.no_grad():
    outputs = model(image_tensor)
    probs = F.softmax(outputs, dim=1)

    dog_prob = probs[0][0].item()  # dog = index 0
    _, predicted = torch.max(outputs, 1)

# ===== KẾT QUẢ =====
if predicted.item() == 0 and dog_prob > 0.5:
    print(f"🐶 Đây là CHÓ ({dog_prob:.2f})")
else:
    print(f"❌ Không phải chó ({dog_prob:.2f})")
# Out:
# 🐶 Đây là CHÓ (1.00)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt

# ===== LOAD MODEL =====
model = models.resnet18(weights=None)
model.fc = nn.Linear(model.fc.in_features, 2)
model.load_state_dict(torch.load("model.pt", map_location='cpu'))
model.eval()

# ===== TRANSFORM =====
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# ===== LOAD ẢNH =====
image = Image.open("3.jpg").convert("RGB")  # 👈 đổi tên ảnh tại đây

# ===== HIỂN THỊ ẢNH =====
plt.imshow(image)
plt.axis('off')
plt.show()

# ===== DỰ ĐOÁN =====
image_tensor = transform(image).unsqueeze(0)

with torch.no_grad():
    outputs = model(image_tensor)
    probs = F.softmax(outputs, dim=1)

    dog_prob = probs[0][0].item()  # dog = index 0
    _, predicted = torch.max(outputs, 1)

# ===== KẾT QUẢ =====
if predicted.item() == 0 and dog_prob > 0.5:
    print(f"🐶 Đây là CHÓ ({dog_prob:.2f})")
else:
    print(f"❌ Không phải chó ({dog_prob:.2f})")
# Out:
# ❌ Không phải chó (0.00)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt

# ===== LOAD MODEL =====
model = models.resnet18(weights=None)
model.fc = nn.Linear(model.fc.in_features, 2)
model.load_state_dict(torch.load("model.pt", map_location='cpu'))
model.eval()

# ===== TRANSFORM =====
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# ===== LOAD ẢNH =====
image = Image.open("2.jpg").convert("RGB")  # 👈 đổi tên ảnh tại đây

# ===== HIỂN THỊ ẢNH =====
plt.imshow(image)
plt.axis('off')
plt.show()

# ===== DỰ ĐOÁN =====
image_tensor = transform(image).unsqueeze(0)

with torch.no_grad():
    outputs = model(image_tensor)
    probs = F.softmax(outputs, dim=1)

    dog_prob = probs[0][0].item()  # dog = index 0
    _, predicted = torch.max(outputs, 1)

# ===== KẾT QUẢ =====
if predicted.item() == 0 and dog_prob > 0.5:
    print(f"🐶 Đây là CHÓ ({dog_prob:.2f})")
else:
    print(f"❌ Không phải chó ({dog_prob:.2f})")
# Out:
# 🐶 Đây là CHÓ (0.99)
